# %% [markdown]
# <a href="https://colab.research.google.com/github/olkasadova/data-and-python/blob/main/Data_Analysis_Worksheets/Data_retrieval_worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data retrieval
# ---
#
# Examples of data being retrieved from a range of sources

# %% [markdown]
# ## From a web page
# ---
#
# The code below reads all the data tables from the Wikipedia page on Glasgow.  The 8th table on the page shows population data over a period of centuries.
#
# The code reads the data from the page into a list of datatables.  The index [7] is used to access the 8th table in the list.  Change the index to see other data tables.  Use len(datatables) to find out how many tables are in the list.

# %%
import pandas as pd
datatables = pd.read_html('https://en.wikipedia.org/wiki/Glasgow#Climate')
df = datatables[5]  #Glasgow population data
print (len (datatables))
df
# Out:
# 23
#   vteClimate data for Abbotsinch[b], elevation: 8 m (26 ft), 1991–2020 normals, extremes 1951–present  \
#                                                                                                 Month
# 0                                Record high °C (°F)
# 1                               Average high °C (°F)
# 2                                 Daily mean °C (°F)
# 3                                Average low °C (°F)
# 4                                 Record low °C (°F)
# 5                  Average precipitation mm (inches)
# 6              Average precipitation days (≥ 1.0 mm)
# 7                        Mean monthly sunshine hours
# 8                             Source: Met Office[92]
#
#                                                                            \
#                       Jan                     Feb                     Mar
# 0             13.5 (56.3)             14.3 (57.7)             18.9 (66.0)
# 1              6.7 (44.1)              7.4 (45.3)              9.2 (48.6)
# 2              4.1 (39.4)              4.5 (40.1)              5.9 (42.6)
# 3              1.5 (34.7)              1.6 (34.9)              2.6 (36.7)
# 4             −17.4 (0.7)             −15.0 (5.0)             −12.5 (9.5)
# 5            157.3 (6.19)            125.0 (4.92)            112.4 (4.43)
# 6                    18.2                    15.2                    14.9
# 7                    45.9                    70.0                   106.1
# 8  Source: Met Office[92]  Source: Met Office[92]  Source: Met Office[92]
#
#                                                                            \
#                       Apr                     May                     Jun
# 0             24.0 (75.2)             27.4 (81.3)             29.6 (85.3)
# 1             12.2 (54.0)             15.4 (59.7)             17.8 (64.0)
# 2              8.2 (46.8)             10.9 (51.6)             13.6 (56.5)
# 3              4.2 (39.6)              6.5 (43.7)              9.4 (48.9)
# 4             −5.4 (22.3)             −3.9 (25.0)              1.2 (34.2)
# 5             73.2 (2.88)             71.9 (2.83)             80.8 (3.18)
# 6                    12.6                    12.2                    12.8
# 7                   148.2                   197.2                   159.2
# 8  Source: Met Office[92]  Source: Met Office[92]  Source: Met Office[92]
#
#                                                                            \
#                       Jul                     Aug                     Sep
# 0             30.1 (86.2)             31.2 (88.2)             26.7 (80.1)
# 1             19.3 (66.7)             18.9 (66.0)             16.5 (61.7)
# 2             15.3 (59.5)             14.9 (58.8)             12.9 (55.2)
# 3             11.2 (52.2)             10.9 (51.6)              9.2 (48.6)
# 4              0.8 (33.4)              1.1 (34.0)             −4.0 (24.8)
# 5             91.9 (3.62)            107.1 (4.22)            109.4 (4.31)
# 6                    13.4                    14.5                    14.3
# 7                   162.7                   152.9                   117.9
# 8  Source: Met Office[92]  Source: Met Office[92]  Source: Met Office[92]
#
#                                                                            \
#                       Oct                     Nov                     Dec
# 0             23.9 (75.0)             16.0 (60.8)             14.6 (58.3)
# 1             12.8 (55.0)              9.3 (48.7)              6.8 (44.2)
# 2              9.6 (49.3)              6.4 (43.5)              4.1 (39.4)
# 3              6.4 (43.5)              3.6 (38.5)              1.4 (34.5)
# 4             −7.1 (19.2)            −10.4 (13.3)            −19.9 (−3.8)
# 5            135.7 (5.34)            145.0 (5.71)            160.7 (6.33)
# 6                    17.2                    18.0                    18.0
# 7                    84.9                    57.5                    41.7
# 8  Source: Met Office[92]  Source: Met Office[92]  Source: Met Office[92]
#
#
#                      Year
# 0             31.2 (88.2)
# 1             12.7 (54.9)
# 2              9.2 (48.6)
# 3              5.7 (42.3)
# 4            −19.9 (−3.8)
# 5         1,370.2 (53.94)
# 6                   181.2
# 7                  1344.1
# 8  Source: Met Office[92]

# %% [markdown]
# ## From a csv file hosted on Github.com
# ---
#
# The code below reads the data table stored in a Comma Separated Values file (this is a text file containing rows of data with each column within the row separated from the next column by a comma).
#
# If you were using Jupyter Notebooks on your device, the url could be replaced with the path to the CSV file.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/Paisley-Weather-Data.csv"
df = pd.read_csv(url)
df

# %% [markdown]
# ## From an Excel file hosted on Github.com
# ---
#
# The code below reads the data table from a sheet in an Excel file.  If you don't specify a sheet then it will assume that you want to read the data from the first sheet in the Excel workbook (sheet_name = 0).  If you don't know the sheet name but know it is the second sheet, you can use sheet_name = 1, or 2 for the third sheet, etc.
#
# If you were using Jupyter Notebooks on your device, the url could be replace with the path to the Excel file.

# %%
import pandas as pd
url = "https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"
df = pd.read_excel(url,sheet_name="Industry Migration")
df

# %% [markdown]
# ## From an API which delivers the data in JSON format
# ---
#
# The code below requests the data from the url.  This is a bit more tricky than the other ways to get the data as how you access the data will depend on how it is organised.
#
# In this example, the data is returned as a dictionary, which will have the key 'data' against which the actual data is stored.  In the example, the data has been taken from the 'data' key/value pair and is stored in json_data.
#
# Again, in this example, the json_data is a list of json_objects but it only has one object in the list.  Try adding the line `print(json_data)` to see this.
#
# data_table is the first object in the json_data list.  Try adding the line `print(data_table)` to see this.
#
# In this example, the data table object has three keys, 'to', 'from' and 'regions'.  The 'regions' value is the data we want to use in our dataframe, so we normalize this json data into a pandas dataframe (df), which you can see as the output.
#
# Each API is likely to deliver its data in a different format and so you will need to be happy to read the documentation and to inspect the data to see what keys and indexes you need to access.
#
# For information on the format of the data, see https://carbon-intensity.github.io/api-definitions/#regional

# %%
import pandas as pd
import requests

url = "https://api.carbonintensity.org.uk/regional"
json_data = requests.get(url).json()['data']
data_table = json_data[0]
df = pd.json_normalize(data_table['regions'])

print (data_table)

print (json_data)
df
# Out:
# {'from': '2023-11-30T18:00Z', 'to': '2023-11-30T18:30Z', 'regions': [{'regionid': 1, 'dnoregion': 'Scottish Hydro Electric Power Distribution', 'shortname': 'North Scotland', 'intensity': {'forecast': 146, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 37}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 48.4}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.5}]}, {'regionid': 2, 'dnoregion': 'SP Distribution', 'shortname': 'South Scotland', 'intensity': {'forecast': 83, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 8.9}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 10.2}, {'fuel': 'gas', 'perc': 18.1}, {'fuel': 'nuclear', 'perc': 43}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 4.3}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 15.6}]}, {'regionid': 3, 'dnoregion': 'Electricity North West', 'shortname': 'North West England', 'intensity': {'forecast': 150, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 15.8}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 7.3}, {'fuel': 'gas', 'perc': 33.3}, {'fuel': 'nuclear', 'perc': 32.7}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 11}]}, {'regionid': 4, 'dnoregion': 'NPG North East', 'shortname': 'North East England', 'intensity': {'forecast': 83, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 16}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 30.7}, {'fuel': 'gas', 'perc': 15.8}, {'fuel': 'nuclear', 'perc': 31.3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 6.1}]}, {'regionid': 5, 'dnoregion': 'NPG Yorkshire', 'shortname': 'Yorkshire', 'intensity': {'forecast': 238, 'index': 'high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 35.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 49.7}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.9}]}, {'regionid': 6, 'dnoregion': 'SP Manweb', 'shortname': 'North Wales & Merseyside', 'intensity': {'forecast': 235, 'index': 'high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0.7}, {'fuel': 'gas', 'perc': 59.2}, {'fuel': 'nuclear', 'perc': 3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 21.4}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.3}]}, {'regionid': 7, 'dnoregion': 'WPD South Wales', 'shortname': 'South Wales', 'intensity': {'forecast': 334, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 84.7}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 15.3}]}, {'regionid': 8, 'dnoregion': 'WPD West Midlands', 'shortname': 'West Midlands', 'intensity': {'forecast': 343, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 4.3}, {'fuel': 'coal', 'perc': 5.8}, {'fuel': 'imports', 'perc': 0.8}, {'fuel': 'gas', 'perc': 72.1}, {'fuel': 'nuclear', 'perc': 3.1}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1.6}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 12.3}]}, {'regionid': 9, 'dnoregion': 'WPD East Midlands', 'shortname': 'East Midlands', 'intensity': {'forecast': 397, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 5.3}, {'fuel': 'coal', 'perc': 11.4}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 72.1}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 11.2 ...
# [{'from': '2023-11-30T18:00Z', 'to': '2023-11-30T18:30Z', 'regions': [{'regionid': 1, 'dnoregion': 'Scottish Hydro Electric Power Distribution', 'shortname': 'North Scotland', 'intensity': {'forecast': 146, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 37}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 48.4}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.5}]}, {'regionid': 2, 'dnoregion': 'SP Distribution', 'shortname': 'South Scotland', 'intensity': {'forecast': 83, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 8.9}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 10.2}, {'fuel': 'gas', 'perc': 18.1}, {'fuel': 'nuclear', 'perc': 43}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 4.3}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 15.6}]}, {'regionid': 3, 'dnoregion': 'Electricity North West', 'shortname': 'North West England', 'intensity': {'forecast': 150, 'index': 'moderate'}, 'generationmix': [{'fuel': 'biomass', 'perc': 15.8}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 7.3}, {'fuel': 'gas', 'perc': 33.3}, {'fuel': 'nuclear', 'perc': 32.7}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 11}]}, {'regionid': 4, 'dnoregion': 'NPG North East', 'shortname': 'North East England', 'intensity': {'forecast': 83, 'index': 'low'}, 'generationmix': [{'fuel': 'biomass', 'perc': 16}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 30.7}, {'fuel': 'gas', 'perc': 15.8}, {'fuel': 'nuclear', 'perc': 31.3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 6.1}]}, {'regionid': 5, 'dnoregion': 'NPG Yorkshire', 'shortname': 'Yorkshire', 'intensity': {'forecast': 238, 'index': 'high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 35.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 49.7}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.9}]}, {'regionid': 6, 'dnoregion': 'SP Manweb', 'shortname': 'North Wales & Merseyside', 'intensity': {'forecast': 235, 'index': 'high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0.7}, {'fuel': 'gas', 'perc': 59.2}, {'fuel': 'nuclear', 'perc': 3}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 21.4}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 14.3}]}, {'regionid': 7, 'dnoregion': 'WPD South Wales', 'shortname': 'South Wales', 'intensity': {'forecast': 334, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coal', 'perc': 0}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 84.7}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 15.3}]}, {'regionid': 8, 'dnoregion': 'WPD West Midlands', 'shortname': 'West Midlands', 'intensity': {'forecast': 343, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 4.3}, {'fuel': 'coal', 'perc': 5.8}, {'fuel': 'imports', 'perc': 0.8}, {'fuel': 'gas', 'perc': 72.1}, {'fuel': 'nuclear', 'perc': 3.1}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 1.6}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 12.3}]}, {'regionid': 9, 'dnoregion': 'WPD East Midlands', 'shortname': 'East Midlands', 'intensity': {'forecast': 397, 'index': 'very high'}, 'generationmix': [{'fuel': 'biomass', 'perc': 5.3}, {'fuel': 'coal', 'perc': 11.4}, {'fuel': 'imports', 'perc': 0}, {'fuel': 'gas', 'perc': 72.1}, {'fuel': 'nuclear', 'perc': 0}, {'fuel': 'other', 'perc': 0}, {'fuel': 'hydro', 'perc': 0}, {'fuel': 'solar', 'perc': 0}, {'fuel': 'wind', 'perc': 11. ...
#     regionid                                   dnoregion  \
# 0          1  Scottish Hydro Electric Power Distribution
# 1          2                             SP Distribution
# 2          3                      Electricity North West
# 3          4                              NPG North East
# 4          5                               NPG Yorkshire
# 5          6                                   SP Manweb
# 6          7                             WPD South Wales
# 7          8                           WPD West Midlands
# 8          9                           WPD East Midlands
# 9         10                                   UKPN East
# 10        11                              WPD South West
# 11        12                                   SSE South
# 12        13                                 UKPN London
# 13        14                             UKPN South East
# 14        15                                     England
# 15        16                                    Scotland
# 16        17                                       Wales
# 17        18                                          GB
#
#                    shortname  \
# 0             North Scotland
# 1             South Scotland
# 2         North West England
# 3         North East England
# 4                  Yorkshire
# 5   North Wales & Merseyside
# 6                South Wales
# 7              West Midlands
# 8              East Midlands
# 9               East England
# 10        South West England
# 11             South England
# 12                    London
# 13        South East England
# 14                   England
# 15                  Scotland
# 16                     Wales
# 17                        GB
#
#                                         generationmix  intensity.forecast  \
# 0   [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 146
# 1   [{'fuel': 'biomass', 'perc': 8.9}, {'fuel': 'c...                  83
# 2   [{'fuel': 'biomass', 'perc': 15.8}, {'fuel': '...                 150
# 3   [{'fuel': 'biomass', 'perc': 16}, {'fuel': 'co...                  83
# 4   [{'fuel': 'biomass', 'perc': 35.4}, {'fuel': '...                 238
# 5   [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'c...                 235
# 6   [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 334
# 7   [{'fuel': 'biomass', 'perc': 4.3}, {'fuel': 'c...                 343
# 8   [{'fuel': 'biomass', 'perc': 5.3}, {'fuel': 'c...                 397
# 9   [{'fuel': 'biomass', 'perc': 0.4}, {'fuel': 'c...                 191
# 10  [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 359
# 11  [{'fuel': 'biomass', 'perc': 1.8}, {'fuel': 'c...                 379
# 12  [{'fuel': 'biomass', 'perc': 0.3}, {'fuel': 'c...                 228
# 13  [{'fuel': 'biomass', 'perc': 0.1}, {'fuel': 'c...                 268
# 14  [{'fuel': 'biomass', 'perc': 7.9}, {'fuel': 'c...                 267
# 15  [{'fuel': 'biomass', 'perc': 1.4}, {'fuel': 'c...                 153
# 16  [{'fuel': 'biomass', 'perc': 0}, {'fuel': 'coa...                 272
# 17  [{'fuel': 'biomass', 'perc': 6.8}, {'fuel': 'c...                 255
#
#    intensity.index
# 0         moderate
# 1              low
# 2         moderate
# 3              low
# 4             high
# 5             high
# 6        very high
# 7        very high
# 8        very high
# 9         moderate
# 10       very high
# 11       very high
# 12            high
# 13            high
# 14            high
# 15        moderate
# 16            high
# 17            high

# %% [markdown]
# ## Exercise - upload a CSV file to your own Github account and write Python code to load it into a dataframe
# ---
#
# 1.  Download the CSV file at this link to your downloads folder on your computer: https://drive.google.com/file/d/15vDkpCKqlRHQt8f8VHER97fIqZytIAtu/view?usp=sharing
#
# 2.  Create a folder called 'Data Sets' and move the CSV file into the Data Sets folder.
#
# 3.  Log in to your Github account and navigate to the repository where you are uploading all your Colab Worksheets
#
# 4.  Click on the Add File button
# ![Add file to Github](https://drive.google.com/uc?id=1szQpVcLg56yPPJc6z4wvK9mCGzSNSa5q)  Select *Upload Files* and then drag the Data Sets folder onto the page (drag the folder rather than the files in it).  Once the folder has uploaded, you will need to commit the changes.  Scroll down the page to see the Commit Changes button.  Before you commit, you can add an extended description *e.g. New folder to store data sets.*
#
# 5.  Click to open the Data Sets folder in your Github repository.  Then click to select the file `housing_in_london_yearly_variables.csv`.  You will need a link to the 'raw' data version of this file.
# ![Get raw data](https://drive.google.com/uc?id=1_B9_1YK35eRpXp5kN2zBZRu0m_CIBn5i)
# Click on 'raw', you will see just the data shown in the page.  Select the URL for this page and copy it.  **This is the link you will need.**
#
# You can now refer to the section above 'From a csv file hosted on Github.com' and create a dataframe from your newly uploaded CSV file.
#
# ### Note:
# for future data set uploads you will just need to navigate to the Data Sets folder in your Github repository and click on Add File there.  You can then just upload the file and it will sit in the Data Sets folder.

# %%
import pandas as pb
url = 'https://raw.githubusercontent.com/olkasadova/data-and-python/main/DataSets/housing_in_london_yearly_variables.csv'
df = pd.read_csv (url)

df
# Out:
#            code                  area        date  median_salary  \
# 0     E09000001        city of london  1999-12-01        33020.0
# 1     E09000002  barking and dagenham  1999-12-01        21480.0
# 2     E09000003                barnet  1999-12-01        19568.0
# 3     E09000004                bexley  1999-12-01        18621.0
# 4     E09000005                 brent  1999-12-01        18532.0
# ...         ...                   ...         ...            ...
# 1066  K03000001         great britain  2019-12-01        30446.0
# 1067  K04000001     england and wales  2019-12-01        30500.0
# 1068  N92000002      northern ireland  2019-12-01        27434.0
# 1069  S92000003              scotland  2019-12-01        30000.0
# 1070  W92000004                 wales  2019-12-01        27500.0
#
#       life_satisfaction mean_salary recycling_pct  population_size  \
# 0                   NaN       48922             0           6581.0
# 1                   NaN       23620             3         162444.0
# 2                   NaN       23128             8         313469.0
# 3                   NaN       21386            18         217458.0
# 4                   NaN       20911             6         260317.0
# ...                 ...         ...           ...              ...
# 1066                NaN       37603           NaN              NaN
# 1067                NaN       37865           NaN              NaN
# 1068                NaN       32083           NaN              NaN
# 1069                NaN       34916           NaN              NaN
# 1070                NaN       31251           NaN              NaN
#
#       number_of_jobs  area_size  no_of_houses  borough_flag
# 0                NaN        NaN           NaN             1
# 1                NaN        NaN           NaN             1
# 2                NaN        NaN           NaN             1
# 3                NaN        NaN           NaN             1
# 4                NaN        NaN           NaN             1
# ...              ...        ...           ...           ...
# 1066             NaN        NaN           NaN             0
# 1067             NaN        NaN           NaN             0
# 1068             NaN        NaN           NaN             0
# 1069             NaN        NaN           NaN             0
# 1070             NaN        NaN           NaN             0
#
# [1071 rows x 12 columns]
